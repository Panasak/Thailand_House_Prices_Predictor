# %% [markdown]
# OVERALL GOAL: Get an understanding for which variables are important, view summary statistics, and visualize the data

# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../data_collect/housing_data_thailand_2021.csv')

# %%
df.head(10)
# Out:
#                                address  areas  beds  baths  \
# 0              หางดง, หางดง, เชียงใหม่   50.0   3.0    3.0
# 1    ลาดพร้าว, ลาดพร้าว, กรุงเทพมหานคร   82.0   3.0    4.0
# 2        หลักสอง, บางแค, กรุงเทพมหานคร   40.0   3.0    2.0
# 3          กระทุ่มล้ม, สามพราน, นครปฐม  100.0   4.0    3.0
# 4             ศาลายา, พุทธมณฑล, นครปฐม   50.0   3.0    2.0
# 5     สันทราย, เมืองเชียงราย, เชียงราย   73.0   4.0    4.0
# 6           ลาดสวาย, ลำลูกกา, ปทุมธานี   84.0   3.0    2.0
# 7  วัดไทรย์, เมืองนครสวรรค์, นครสวรรค์    NaN   4.0    4.0
# 8           บางละมุง, บางละมุง, ชลบุรี   73.0   3.0    3.0
# 9             ศรีราชา, ศรีราชา, ชลบุรี    NaN   3.0    3.0
#
#                                         descriptions     listing_date  \
# 0  รหัส  :  SH0222  🍭บ้าน สวย หลังใหญ่ ใกล้เมือง ...  19 October 2021
# 1  ขายเดี่ยว 2 ชั้นไพรเวท เนอวานา เรสสิเดนซ์ หลัง...  18 October 2021
# 2  **ฟังก์ชันบ้าน**ห้องนอน : 3 ห้องห้องน้ำ : 2 ห้...  18 October 2021
# 3  ขายบ้านเดี่ยว 2ชั้น หมู่บ้าน  มณฑลทิพย์ ต. กระ...  18 October 2021
# 4  ขายบ้านเดี่ยว หมู่บ้านคณาสิริ ศาลายา ราคาเพียง...  18 October 2021
# 5  หมู่บ้านศิริพรการ์เด้นโฮม 9 ตั้งอยู่ที่ สันนาเ...  18 October 2021
# 6  ขายบ้านเดี่ยวลำลูกกา คลอง4 ขนาด 84 ตรว  ขายบ้า...  17 October 2021
# 7  #579796บ้านเดี่ยว  2 ชั้น อยู่ในโครงการ ดีพร้อ...  19 October 2021
# 8  ขายบ้านเดี่ยวหลังริมบางละมุง พัทยา⭐️ขาย 3.99 ล...  17 October 2021
# 9  ขาย บ้านคันทรีโฮม 3 ศรีราชา - หนองยายบู่ 99.6 ...  16 October 2021
#
#        prices  status                                             titles
# 0   2,490,000    ใหม่  บ้านเดี่ยว 2 ชั้น พท. ที่ใช้สอย 135 ตร. ม.  ใก...
# 1  23,900,000  มือสอง  ขายเดี่ยว 2 ชั้นไพรเวท เนอวานา เรสสิเดนซ์ หลัง...
# 2   3,990,000  มือสอง  บ้านแฝด ม. ปารวีร์ เพชรเกษม63 ใกล้เดอะมอลล์บาง...
# 3   5,500,000  มือสอง  ขายบ้านเดี่ยว 100 ตรว หมู่บ้านมณฑลทิพย์ พุทธมณ...
# 4   4,200,000  มือสอง  บ้านเดี่ยว คณาสิริ ศาลายา ราคาเพียง 4.2 บิ้วอิ...
# 5   3,200,000  มือสอง  มองหาบ้านสำหรับครอบครัวขนาดใหญ่อยู่รึป่าว ? นี...
# 6   4,950,000  มือสอง  ขายบ้านเดี่ยวลำลูกกา คลอง4  ขนาด 84 ตรว มี 3  ...
# 7  10,500,000  มือสอง  ขายด่วน! บ้านเดี่ยว  2 ชั้น โครงการ ดีพร้อม วิ...
# 8   3,999,000  มือสอง                                บ้านเดี่ยว บางละมุง
# 9   5,300,000  มือสอง  ขาย บ้านคันทรีโฮม 3 ศรีราชา - หนองยายบู่ 99.6 ...

# %%
# convert prices to float
df['prices'] = df['prices'].str.replace(',','').astype(int)

# %%
df['prices'].max()
# Out:
# 249000000

# %%
# histogram of prices
fig, ax = plt.subplots(figsize=(12,8))
sns.distplot(df['prices'], ax=ax, bins=1000)
ax.set_xlim(3600,249000001)
plt.show()

# %%
# change the font to Thai
import matplotlib
import matplotlib.font_manager as fm

matplotlib.font_manager.fontManager.addfont('THSarabunNew.ttf')

matplotlib.rc('font', family = 'TH Sarabun New')
matplotlib.rcParams.update({'font.size': 20})

# %%
# countplot of status
plt.figure(figsize=(12,8))
sns.countplot(x='status',data=df)

# %%
#heatmap of the corrolation of evething
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,cmap='viridis')

# %%
#convert listing_dates to date time
df['listing_date'] = pd.to_datetime(df['listing_date'])

# %%
#scatterplot between listing dates and prices
plt.figure(figsize=(12,8))
sns.scatterplot(x='prices',y='listing_date',data=df,)

# %%
#scatterplot between area and prices
plt.figure(figsize=(12,8))
sns.scatterplot(x='prices',y='areas',data=df,)

# %%
#boxplot between prices and bed
plt.figure(figsize=(12,8))
sns.boxplot(x='beds',y='prices',data=df)

# %%
#boxplot between prices and bed
plt.figure(figsize=(12,8))
sns.boxplot(x='baths',y='prices',data=df)

# %%
# fill in missing subdistrict with ''
def fix_address(address):
    if address.count(",") >= 2:
        return address
    else:
        result = ' , '+address
        return result

# %%
# apply the def
df['address'] = df['address'].apply(lambda x: fix_address(x))

# %%
df
# Out:
#                                 address  areas  beds  baths  \
# 0               หางดง, หางดง, เชียงใหม่   50.0   3.0    3.0
# 1     ลาดพร้าว, ลาดพร้าว, กรุงเทพมหานคร   82.0   3.0    4.0
# 2         หลักสอง, บางแค, กรุงเทพมหานคร   40.0   3.0    2.0
# 3           กระทุ่มล้ม, สามพราน, นครปฐม  100.0   4.0    3.0
# 4              ศาลายา, พุทธมณฑล, นครปฐม   50.0   3.0    2.0
# ...                                 ...    ...   ...    ...
# 2395             โป่ง, บางละมุง, ชลบุรี  100.0   5.0    5.0
# 2396             โป่ง, บางละมุง, ชลบุรี  100.0   5.0    3.0
# 2397           หนองขาม, ศรีราชา, ชลบุรี   40.0   2.0    1.0
# 2398        บางแขม, เมืองนครปฐม, นครปฐม    NaN   3.0    3.0
# 2399  บ้านใหม่, เมืองปทุมธานี, ปทุมธานี   65.0   3.0    3.0
#
#                                            descriptions listing_date  \
# 0     รหัส  :  SH0222  🍭บ้าน สวย หลังใหญ่ ใกล้เมือง ...   2021-10-19
# 1     ขายเดี่ยว 2 ชั้นไพรเวท เนอวานา เรสสิเดนซ์ หลัง...   2021-10-18
# 2     **ฟังก์ชันบ้าน**ห้องนอน : 3 ห้องห้องน้ำ : 2 ห้...   2021-10-18
# 3     ขายบ้านเดี่ยว 2ชั้น หมู่บ้าน  มณฑลทิพย์ ต. กระ...   2021-10-18
# 4     ขายบ้านเดี่ยว หมู่บ้านคณาสิริ ศาลายา ราคาเพียง...   2021-10-18
# ...                                                 ...          ...
# 2395  รหัสประกาศ: #RT0357  บ้านเดี่ยวพร้อมสระว่ายน้ำ...   2021-09-13
# 2396  รหัสประกาศ: #RT0356  บ้านเเดี่ยว พร้อมสระว่ายน...   2021-09-13
# 2397  #579347ขายบ้านเดี่ยว 40 ตร. ว. โครงการประดิษฐ์...   2021-09-23
# 2398  บ้านเดี่ยว 2 ชั้น หมู่บ้านเดอะชารีนา แบบ B เลข...   2021-09-15
# 2399  ใกล้เมืองทองธานี ใกล้โรงเรียนพระหฤทัย ใกล้สะพา...   2021-09-15
#
#         prices  status                                             titles
# 0      2490000    ใหม่  บ้านเดี่ยว 2 ชั้น พท. ที่ใช้สอย 135 ตร. ม.  ใก...
# 1     23900000  มือสอง  ขายเดี่ยว 2 ชั้นไพรเวท เนอวานา เรสสิเดนซ์ หลัง...
# 2      3990000  มือสอง  บ้านแฝด ม. ปารวีร์ เพชรเกษม63 ใกล้เดอะมอลล์บาง...
# 3      5500000  มือสอง  ขายบ้านเดี่ยว 100 ตรว หมู่บ้านมณฑลทิพย์ พุทธมณ...
# 4      4200000  มือสอง  บ้านเดี่ยว คณาสิริ ศาลายา ราคาเพียง 4.2 บิ้วอิ...
# ...        ...     ...                                                ...
# 2395   9900000  มือสอง                 สำหรับ ขาย บ้าน 5 ห้องนอน ที่ โป่ง
# 2396   7500000  มือสอง                 สำหรับ ขาย บ้าน 5 ห้องนอน ที่ โป่ง
# 2397   1800000  มือสอง  ขายด่วน! บ้านเดี่ยว 40 ตร. ว. โครงการประดิษฐ์ไ...
# 2398   4600000     NaN                                      ขายบ้านเดี่ยว
# 2399   7850000  มือสอง  บ้านเดี่ยว 2 ชั้น  65.1 ตร. ว. หมู่บ้านสราญสิร...
#
# [2400 rows x 9 columns]

# %%
#PROBLEM: SOME PROVES ARE STILL NOT CORRECT
address_split = df['address'].apply(lambda x:x.split(','))

# %%
# seperate address into subdistricts, districts, and province
sub = []
dis = []
prov = []
for a_l in address_split:
    if a_l.count(',') > 2:
        sub.append(a_l[:2])
        dis.append(a_l[2])
        prov.append(a_l[3])
    else:
        sub.append(a_l[0])
        dis.append(a_l[1])
        prov.append(a_l[2])
df['sub'] = sub
df['dis'] = dis
df['prov'] = prov

# %%
df.head(10)
# Out:
#                                address  areas  beds  baths  \
# 0              หางดง, หางดง, เชียงใหม่   50.0   3.0    3.0
# 1    ลาดพร้าว, ลาดพร้าว, กรุงเทพมหานคร   82.0   3.0    4.0
# 2        หลักสอง, บางแค, กรุงเทพมหานคร   40.0   3.0    2.0
# 3          กระทุ่มล้ม, สามพราน, นครปฐม  100.0   4.0    3.0
# 4             ศาลายา, พุทธมณฑล, นครปฐม   50.0   3.0    2.0
# 5     สันทราย, เมืองเชียงราย, เชียงราย   73.0   4.0    4.0
# 6           ลาดสวาย, ลำลูกกา, ปทุมธานี   84.0   3.0    2.0
# 7  วัดไทรย์, เมืองนครสวรรค์, นครสวรรค์    NaN   4.0    4.0
# 8           บางละมุง, บางละมุง, ชลบุรี   73.0   3.0    3.0
# 9             ศรีราชา, ศรีราชา, ชลบุรี    NaN   3.0    3.0
#
#                                         descriptions listing_date    prices  \
# 0  รหัส  :  SH0222  🍭บ้าน สวย หลังใหญ่ ใกล้เมือง ...   2021-10-19   2490000
# 1  ขายเดี่ยว 2 ชั้นไพรเวท เนอวานา เรสสิเดนซ์ หลัง...   2021-10-18  23900000
# 2  **ฟังก์ชันบ้าน**ห้องนอน : 3 ห้องห้องน้ำ : 2 ห้...   2021-10-18   3990000
# 3  ขายบ้านเดี่ยว 2ชั้น หมู่บ้าน  มณฑลทิพย์ ต. กระ...   2021-10-18   5500000
# 4  ขายบ้านเดี่ยว หมู่บ้านคณาสิริ ศาลายา ราคาเพียง...   2021-10-18   4200000
# 5  หมู่บ้านศิริพรการ์เด้นโฮม 9 ตั้งอยู่ที่ สันนาเ...   2021-10-18   3200000
# 6  ขายบ้านเดี่ยวลำลูกกา คลอง4 ขนาด 84 ตรว  ขายบ้า...   2021-10-17   4950000
# 7  #579796บ้านเดี่ยว  2 ชั้น อยู่ในโครงการ ดีพร้อ...   2021-10-19  10500000
# 8  ขายบ้านเดี่ยวหลังริมบางละมุง พัทยา⭐️ขาย 3.99 ล...   2021-10-17   3999000
# 9  ขาย บ้านคันทรีโฮม 3 ศรีราชา - หนองยายบู่ 99.6 ...   2021-10-16   5300000
#
#    status                                             titles         sub  \
# 0    ใหม่  บ้านเดี่ยว 2 ชั้น พท. ที่ใช้สอย 135 ตร. ม.  ใก...       หางดง
# 1  มือสอง  ขายเดี่ยว 2 ชั้นไพรเวท เนอวานา เรสสิเดนซ์ หลัง...    ลาดพร้าว
# 2  มือสอง  บ้านแฝด ม. ปารวีร์ เพชรเกษม63 ใกล้เดอะมอลล์บาง...     หลักสอง
# 3  มือสอง  ขายบ้านเดี่ยว 100 ตรว หมู่บ้านมณฑลทิพย์ พุทธมณ...  กระทุ่มล้ม
# 4  มือสอง  บ้านเดี่ยว คณาสิริ ศาลายา ราคาเพียง 4.2 บิ้วอิ...      ศาลายา
# 5  มือสอง  มองหาบ้านสำหรับครอบครัวขนาดใหญ่อยู่รึป่าว ? นี...     สันทราย
# 6  มือสอง  ขายบ้านเดี่ยวลำลูกกา คลอง4  ขนาด 84 ตรว มี 3  ...     ลาดสวาย
# 7  มือสอง  ขายด่วน! บ้านเดี่ยว  2 ชั้น โครงการ ดีพร้อม วิ...    วัดไทรย์
# 8  มือสอง                                บ้านเดี่ยว บางละมุง    บางละมุง
# 9  มือสอง  ขาย บ้านคันทรีโฮม 3 ศรีราชา - หนองยายบู่ 99.6 ...     ศรีราชา
#
#                dis            prov
# 0            หางดง       เชียงใหม่
# 1         ลาดพร้าว   กรุงเทพมหานคร
# 2            บางแค   กรุงเทพมหานคร
# 3          สามพราน          นครปฐม
# 4         พุทธมณฑล          นครปฐม
# 5    เมืองเชียงราย        เชียงราย
# 6          ลำลูกกา        ปทุมธานี
# 7   เมืองนครสวรรค์       นครสวรรค์
# 8         บางละมุง          ชลบุรี
# 9          ศรีราชา          ชลบุรี

# %%
df[['prices','prov']].groupby('prov').mean().plot(kind='bar',figsize=(16,8))

# %%
df.corr()['loan_repaid'].sort_values().drop('loan_repaid').plot(kind='bar')

# %%
# relationship bettween province and price
# average price for each province
sns.barplot(x=,y=df['prices'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-e218aba17f8b> in <module>
#       1 # relationship bettween province and price
# ----> 2 sns.barplot(x=df['prov'].unique(),y=df['prices'])
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1600                  errwidth, capsize, dodge):
#    1601         """Initialize the plotter."""
# -> 1602         self.establish_variables(x, y, hue, data, orient,
#    1603                                  order, hue_order, units)
#    1604         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     201
#     202                 # Group the numeric data
# --> 203                 plot_data, value_label = self._group_longform(vals, groups,
#     204                                                               group_names)
#     205
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in _group_longform(self, vals, grouper, order)
#     248
#     249         # Group the val data
# --> 250         grouped_vals = vals.groupby(grouper)
#     251         out_data = []
#     252         for g in order:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    1676         axis = self._get_axis_number(axis)
#    1677
# -> 1678         return groupby_generic.SeriesGroupBy(
#    1679             obj=self,
#    1680             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
#     404                 obj,
#     405                 keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     615         # allow us to passing the actual Grouping as the gpr
#     616         ping = (
# --> 617             Grouping(
#     618                 group_axis,
#     619                 gpr,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     254         self.name = name
#     255         self.level = level
# --> 256         self.grouper = _convert_grouper(index, grouper)
#     257         self.all_grouper = None
#     258         self.index = index
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _convert_grouper(axis, grouper)
#     655     elif isinstance(grouper, (list, Series, Index, np.ndarray)):
#     656         if len(grouper) != len(axis):
# --> 657             raise ValueError("Grouper and axis must be same length")
#     658         return grouper
#     659     else:
#
# ValueError: Grouper and axis must be same length
